# %%
import pandas as pd

# %%
videosUS_path = "./videosUS.csv"
df = pd.read_csv(videosUS_path)

# %%
df
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# ...            ...           ...
# 41410  BZt0qjTWNhw      18.14.06
# 41411  1h7KV2sjUWY      18.14.06
# 41412  D6Oy4LfoqsU      18.14.06
# 41413  oV0zkMe1K8s      18.14.06
# 41414  ooyjaVdt-jA      18.14.06
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 41410                       The Cat Who Caught the Laser
# 41411                         True Facts : Ant Mutualism
# ...

# %%
df.isna()
# Out:
#        video_id  trending_date  title  channel_title  category_id  \
# 0         False          False  False          False        False
# 1         False          False  False          False        False
# 2         False          False  False          False        False
# 3         False          False  False          False        False
# 4         False          False  False          False        False
# ...         ...            ...    ...            ...          ...
# 41410     False          False  False          False        False
# 41411     False          False  False          False        False
# 41412     False          False  False          False        False
# 41413     False          False  False          False        False
# 41414     False          False  False          False        False
#
#        publish_time   tags  views  likes  dislikes  comment_count  \
# 0             False  False  False  False     False          False
# ...

# %%
# count of null values in each column
print(df.isnull().sum())
# Out:
# video_id                     0
# trending_date              466
# title                      466
# channel_title              466
# category_id                466
# publish_time               466
# tags                       466
# views                      466
# likes                      466
# dislikes                   466
# comment_count              466
# thumbnail_link             466
# comments_disabled          466
# ratings_disabled           466
# video_error_or_removed     466
# description               1036
# dtype: int64

# %% [markdown]
# What assumptions can you make about these missing values ( why do we have them missing ? )

# %% [markdown]
# - Missing Completely Randomly.
# - Data entry errors.
# - The individual dies or drops out before sampling.
# - when collecting the data
# - the study participant simply may have forgotten to answer it

# %% [markdown]
# 2 - Get the mean , median , quartiles of each numerical variable within this dataset.

# %%
df.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  40949.000000  4.094900e+04  4.094900e+04  4.094900e+04   4.094900e+04
# mean      19.972429  2.360785e+06  7.426670e+04  3.711401e+03   8.446804e+03
# std        7.568327  7.394114e+06  2.288853e+05  2.902971e+04   3.743049e+04
# min        1.000000  5.490000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       17.000000  2.423290e+05  5.424000e+03  2.020000e+02   6.140000e+02
# 50%       24.000000  6.818610e+05  1.809100e+04  6.310000e+02   1.856000e+03
# 75%       25.000000  1.823157e+06  5.541700e+04  1.938000e+03   5.755000e+03
# max       43.000000  2.252119e+08  5.613827e+06  1.674420e+06   1.361580e+06

# %% [markdown]
# 3 - Spot the possible outliers in your dataset and get rid of them.

# %%
df['views'] = (df.views - df.views.mean())/df.views.std()
df = df[df['views'] > 3]

# %%
df
# Out:
#           video_id trending_date  \
# 73     2Vv-BfVoq4g      17.14.11
# 342    2Vv-BfVoq4g      17.15.11
# 583    2Vv-BfVoq4g      17.16.11
# 778    n1WpP7iowLc      17.17.11
# 1010   n1WpP7iowLc      17.18.11
# ...            ...           ...
# 41335  xTlNMmZKwpA      18.14.06
# 41341  1J76wN0TPI4      18.14.06
# 41373  aEM2kOrrNJI      18.14.06
# 41391  QgOXIEhHU1Y      18.14.06
# 41404  n_W54baizX8      18.14.06
#
#                                                    title      channel_title  \
# 73           Ed Sheeran - Perfect (Official Music Video)         Ed Sheeran
# 342          Ed Sheeran - Perfect (Official Music Video)         Ed Sheeran
# 583          Ed Sheeran - Perfect (Official Music Video)         Ed Sheeran
# 778           Eminem - Walk On Water (Audio) ft. Beyoncé         EminemVEVO
# 1010          Eminem - Walk On Water (Audio) ft. Beyoncé         EminemVEVO
# ...                                                  ...                ...
# ...

# %% [markdown]
# 4 - How many unique categories do you have ?

# %%
print(df.nunique(axis=1))
# Out:
# 73       14
# 342      14
# 583      14
# 778      14
# 1010     14
#          ..
# 41335    14
# 41341    14
# 41373    14
# 41391    14
# 41404    14
# Length: 519, dtype: int64

# %%
print(df['category_id'].value_counts())
# Out:
# 10.0    359
# 24.0     89
# 1.0      27
# 22.0     16
# 28.0     13
# 26.0      4
# 17.0      4
# 2.0       4
# 23.0      3
# Name: category_id, dtype: int64

# %% [markdown]
# Is there any column that we need to adjust its type ?

# %% [markdown]
# Get how many tags you have and which are the most common tags ?

# %%
print(df['tags'].value_counts(ascending=True))
# Out:
# humility|"Gorillaz Humanz"|"the now now"|"george benson"|"Venice Beach"|"jamie hewlett"|"damon albarn"|"new album"|"Los Angeles"|"Jack Black"|"Free Murdoc"|"Hollywood"|"Demon Dayz"|"Gorillaz The Now Now"|"g is the magic number"|"lake zurich"|"Gorillaz Leak"|"gorillaz"|"jack black"                                                                                                                                                                                                                                1
# ...

# %% [markdown]
# - The most common tags are the one that have tha count of 25 and they are : "Childish Gambino" | "Rap" | "This Is America" | "mcDJ Recording/RCA Records"
